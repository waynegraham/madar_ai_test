# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from src.alto import load_alto
from src.segmentation import alto_to_regions
from src.visualization import display_regions, compare_regions

# %%
DATA = Path("../data")

IMAGE_ID = "1280_AB010309_0005"

source = (
    DATA / "images" /
    f"{IMAGE_ID}.tif"
)

prediction_path = (
    DATA / "predictions" /
    "escriptorium" /
    f"{IMAGE_ID}.xml"
)

ground_truth_path = (
    DATA / "ground-truth" /
    "alto" /
    f"{IMAGE_ID}.xml"
)

# %%
prediction = load_alto(
    prediction_path
)

ground_truth = load_alto(
    ground_truth_path
)

prediction_regions = alto_to_regions(
    prediction
)

ground_truth_regions = alto_to_regions(
    ground_truth
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 prediction = load_alto(
#       2     prediction_path
#       3 )
#       4
#
# File ~/Downloads/madar_ai_test/src/alto.py:215, in load_alto(path)
#     197 """
#     198 Parse an eScriptorium ALTO XML export.
#     199
#    (...)    210             print(line.text)
#     211 """
#     213 path = Path(path)
# --> 215 tree = ET.parse(path)
#     216 root = tree.getroot()
#     218 tags = _parse_tags(root)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.7/Frameworks/Python.framework/Versions/3.14/lib/python3.14/xml/etree/ElementTree.py:1227, in parse(source, parser)
#    1218 """Parse XML document into element tree.
#    1219
#    1220 *source* is a filename or file object containing XML data,
#    (...)   1224
#    1225 """
#    1226 tree = ElementTree()
# -> 1227 tree.parse(source, parser)
# ...
