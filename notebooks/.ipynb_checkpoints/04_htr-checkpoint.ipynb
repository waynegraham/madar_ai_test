# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import pandas as pd

from IPython.display import display

from src.annotation import (
    load_annotations,
    annotations_to_regions,
)

from src.images import (
    crop_normalized_bbox,
)

from src.lmstudio import (
    analyze_image,
    load_prompt,
    save_result,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA = Path("../data")
PROMPTS = Path("../prompts")

IMAGE_ID = "1280_AB010309_0005"

source = (
    DATA
    / "images"
    / f"{IMAGE_ID}.tif"
)

annotation_path = (
    DATA
    / "ground-truth"
    / f"{IMAGE_ID}.json"
)

crop_dir = (
    DATA
    / "crops"
    / IMAGE_ID
)

crop_dir.mkdir(
    parents=True,
    exist_ok=True,
)

MODEL_8B = "qwen3-vl-8b-instruct-mlx"
MODEL_30B = "qwen3-vl-30b-a3b-instruct-mlx"

# %%
document = load_annotations(
    annotation_path
)

human_regions = annotations_to_regions(
    document
)

for i, region in enumerate(human_regions):
    print(
        i,
        region.id,
        region.region_type,
        region.bbox,
    )
# Out:
# 0 human-a305f6fb stamp_or_seal (238.5746778631845, 396.4179187431684, 341.07358630423516, 445.76856809381775)
# 1 human-a248a412 stamp_or_seal (459.2320502015575, 558.3226806479305, 702.666957749053, 692.5218148470645)
# 2 human-c638ca7b archival_mark (248.53984951717547, 8.539130864380603, 632.9107561711157, 129.75125207650186)
# 3 human-ef7105b4 stamp_or_seal (188.74881959322923, 746.2014685267183, 463.5028380532679, 797.2837196089692)
# 4 human-382299a4 main_text (133.2285775209935, 275.2057975310472, 859.2625123117695, 397.2837196089693)
# 5 human-dbb419a1 handwritten_annotation (497.6691408669517, 428.45255077780047, 632.9107561711157, 521.0932434184932)
# 6 human-855bed91 handwritten_annotation (163.12409248296657, 122.8248451500949, 409.4061919316023, 191.22311354836327)
# 7 human-81f43a2d handwritten_annotation (127.53419371871286, 639.7079620332116, 433.607323091295, 721.959044284294)

# %% [markdown]
# ## Select text-bearing regions

# %%
TEXT_REGION_TYPES = {
    "main_text",
    "marginal_text",
    "handwritten_annotation",
}

# %%
text_regions = [
    region
    for region in human_regions
    if region.region_type in TEXT_REGION_TYPES
]

len(text_regions)
# Out:
# 4

# %% [markdown]
# ## Create high-resolution crops

# %%
crop_records = []

for region in text_regions:

    crop = crop_normalized_bbox(
        source,
        region.bbox,
        padding=30,
    )

    crop_path = (
        crop_dir
        / f"{region.id}.png"
    )

    crop.save(crop_path)

    crop_records.append({
        "region_id": region.id,
        "region_type": region.region_type,
        "crop_path": crop_path,
    })

# %% [markdown]
# ## Load HTR Prompt

# %%
htr_prompt = load_prompt(
    PROMPTS / "htr-v1.txt"
)

# %% [markdown]
# ## Test one crop

# %%
test_record = crop_records[0]

display(
    test_record["crop_path"]
)
# Out:
# PosixPath('../data/crops/1280_AB010309_0005/human-382299a4.png')

# %%
# Qwen 8B 

response_8b = analyze_image(
    test_record["crop_path"],
    htr_prompt,
    model=MODEL_8B,
    temperature=0.0,
    max_tokens=4096,
)

response_8b.parsed
# Out:
# {'script': 'Arabic',
#  'language': 'Persian',
#  'transcription': 'بی مCORD بی مرحم عباس باش هدیم الهب زماد شهیری\nمرحم الامی باش دالهی فادیه قسیلک داره اری کیل\nمصفف خلاصی بلك ایندیه دفع مطهر وفق',
#  'confidence': 0.95}

# %%
result_path = (
    DATA
    / "results"
    / IMAGE_ID
    / "qwen3-vl-8b"
    / "htr"
    / f"{test_record['region_id']}-htr-v1.json"
)

save_result(
    response_8b,
    result_path,
    task="htr",
    prompt_version="htr-v1",
)
# Out:
# PosixPath('../data/results/1280_AB010309_0005/qwen3-vl-8b/htr/human-382299a4-htr-v1.json')

# %%
## 30B 

response_30b = analyze_image(
    test_record["crop_path"],
    htr_prompt,
    model=MODEL_30B,
    temperature=0.0,
    max_tokens=4096,
)

response_30b.parsed
# Out:
# {'script': 'Naskh',
#  'language': 'Arabic',
#  'transcription': 'كبير معدوبى مصمم عبادى باتا هيلد كر اليعب نما د شبه بارى مصمم الامى باتا والعى فاديه قديك دارته ارى كيل مصطفى خلودى بلغ اندية وفه طيه ونفى',
#  'confidence': 0.95}

# %%
result_path = (
    DATA
    / "results"
    / IMAGE_ID
    / "qwen3-vl-30b"
    / "htr"
    / f"{test_record['region_id']}-htr-v1.json"
)

save_result(
    response_30b,
    result_path,
    task="htr",
    prompt_version="htr-v1",
)
# Out:
# PosixPath('../data/results/1280_AB010309_0005/qwen3-vl-30b/htr/human-382299a4-htr-v1.json')

# %% [markdown]
# ## Compare results

# %%
comparison = pd.DataFrame([
    {
        "model": "Qwen 8B",
        "script": response_8b.parsed.get("script"),
        "language": response_8b.parsed.get("language"),
        "confidence": response_8b.parsed.get("confidence"),
        "transcription": response_8b.parsed.get("transcription"),
    },
    {
        "model": "Qwen 30B",
        "script": response_30b.parsed.get("script"),
        "language": response_30b.parsed.get("language"),
        "confidence": response_30b.parsed.get("confidence"),
        "transcription": response_30b.parsed.get("transcription"),
    },
])

comparison
# Out:
#       model  script language  confidence  \
# 0   Qwen 8B  Arabic  Persian        0.95
# 1  Qwen 30B   Naskh   Arabic        0.95
#
#                                        transcription
# 0  بی مCORD بی مرحم عباس باش هدیم الهب زماد شهیری...
# 1  كبير معدوبى مصمم عبادى باتا هيلد كر اليعب نما ...
