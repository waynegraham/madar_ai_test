# %% [markdown]
# # Setup
#
# Import libraries for analysis

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path

from src.images import create_vlm_derivative
from src.lmstudio import (
    analyze_image,
    load_prompt,
    save_result
)
from src.visualization import (
    display_regions,
    compare_regions
)
from src.segmentation import (
    vlm_json_to_regions,
    alto_to_regions
)

from src.alto import load_alto

# %% [markdown]
# ## Setting
#
# Import model, image, derivative, and segmentation prompt

# %%
IMAGE_ID = "1280_AB010309_0005"

DATA = Path("../data")

source = DATA / "images" / f"{IMAGE_ID}.tif"
alto_path = DATA / "alto" / f"{IMAGE_ID}.xml"
derivative = DATA / "derivatives" / f"{IMAGE_ID}.png"

prompt_path = Path("../prompts/segmentation-v1.txt")

MODEL_8B = "qwen3-vl-8b-instruct-mlx"
MODEL_30B = "qwen3-vl-30b-a3b-instruct-mlx"

PROMPT_VERSION = "segmentation-v1"

# %% [markdown]
# ## Create Derivative

# %%
create_vlm_derivative(
    source,
    derivative,
    max_dimension=2048,
)

print(source)
print(derivative)
# Out:
# ../data/images/1280_AB010309_0005.tif
# ../data/derivatives/1280_AB010309_0005.png

# %% [markdown]
# ## Load Prompt

# %%
prompt = load_prompt(prompt_path)

print(prompt)
# Out:
# You are analyzing a historical archival document.
#
# Identify all major visually distinct regions on the page.
#
# Use only these region types:
#
# - main_text
# - marginal_text
# - stamp_or_seal
# - handwritten_annotation
# - archival_mark
# - illustration
# - unknown
#
# Return ONLY valid JSON with this structure:
#
# {
#   "regions": [
#     {
#       "type": "stamp_or_seal",
#       "bbox": [x1, y1, x2, y2],
#       "confidence": 0.95
#     }
#   ]
# }
#
# Bounding box coordinates must use a normalized coordinate system
# from 0 to 1000:
#
# - x=0 is the left edge
# - x=1000 is the right edge
# - y=0 is the top edge
# - y=1000 is the bottom edge
#
# Identify visually observable regions only.
#
# Do not transcribe any text.
# Do not identify languages.
# Do not determine whether anything is related to waqf.
# Do not explain your answer.

# %% [markdown]
# ## Load eScriptorium baseline

# %%
alto = load_alto(alto_path)

escriptorium_regions = alto_to_regions(alto)

print(
    f"eScriptorium regions: "
    f"{len(escriptorium_regions)}"
)
# Out:
# eScriptorium regions: 11

# %% [markdown]
# ## Inspect baseline

# %%
for region in escriptorium_regions:
    print(
        f"{region.region_type:25}",
        region.bbox,
        region.confidence,
    )
# Out:
# main_text                 (125.87959343236903, 279.83832620066573, 884.6755277560594, 552.3062291963862) 0.8283322203030805
# main_text                 (257.6231430805317, 113.17165953399905, 375.6841282251759, 132.4298621017594) None
# main_text                 (181.00078186082877, 673.323823109843, 491.00860046911646, 718.9728958630528) None
# main_text                 (175.52775605942142, 743.2239657631953, 485.5355746677091, 789.1107941036614) None
# main_text                 (240.03127443315088, 0.0, 605.9421422986708, 19.020446980504044) None
# main_text                 (5.473025801407349, 489.7765097479791, 9.382329945269742, 495.7203994293866) None
# main_text                 (0.0, 893.96100808369, 20.32838154808444, 955.777460770328) None
# main_text                 (10.946051602814698, 963.1478839752734, 14.855355746677093, 969.091773656681) None
# main_text                 (147.77169663799845, 536.6143604374703, 168.49100860046912, 538.9919163100333) None
# main_text                 (241.20406567630963, 29.957203994293863, 567.6309616888194, 89.1583452211127) None
# main_text                 (5.473025801407349, 476.4621968616263, 9.382329945269742, 479.0775083214456) None

# %% [markdown]
# ## Qwen 8B

# %%
response_8b = analyze_image(
    derivative,
    prompt,
    model=MODEL_8B,
    temperature=0.0,
    max_tokens=4096,
)

print(
    f"Qwen 8B inference: "
    f"{response_8b.elapsed_seconds:.1f}s"
)
# Out:
# Qwen 8B inference: 12.4s

# %% [markdown]
# ### Parse 8B regions

# %%
qwen_8b_regions = vlm_json_to_regions(
    response_8b.parsed,
    source="qwen3-vl-8b",
)

print(
    f"Qwen 8B regions: "
    f"{len(qwen_8b_regions)}"
)

for region in qwen_8b_regions:
    print(
        f"{region.region_type:25}",
        region.bbox,
        region.confidence,
    )
# Out:
# Qwen 8B regions: 9
# main_text                 (145.0, 278.0, 873.0, 409.0) 0.95
# handwritten_annotation    (173.0, 124.0, 395.0, 186.0) 0.92
# handwritten_annotation    (120.0, 467.0, 513.0, 638.0) 0.94
# handwritten_annotation    (247.0, 6.0, 619.0, 145.0) 0.93
# handwritten_annotation    (128.0, 643.0, 417.0, 720.0) 0.95
# stamp_or_seal             (243.0, 391.0, 330.0, 450.0) 0.89
# stamp_or_seal             (460.0, 561.0, 700.0, 698.0) 0.92
# stamp_or_seal             (201.0, 753.0, 460.0, 793.0) 0.85
# archival_mark             (459.0, 907.0, 692.0, 961.0) 0.83

# %% [markdown]
# ## Save 8B result

# %%
result_8b_path = (
    DATA
    / "results"
    / IMAGE_ID
    / "qwen3-vl-8b"
    / f"{PROMPT_VERSION}.json"
)

save_result(
    response_8b,
    result_8b_path,
    task="segmentation",
    prompt_version=PROMPT_VERSION,
)

print(result_8b_path)
# Out:
# ../data/results/1280_AB010309_0005/qwen3-vl-8b/segmentation-v1.json

# %% [markdown]
# ### Visualize 8B

# %%
display_regions(
    source,
    qwen_8b_regions,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 display_regions(
#       2     source,
#       3     qwen_8b_regions,
#       4 )
#
# File ~/Downloads/madar_ai_test/src/visualization.py:38, in display_regions(image, regions, coordinate_max, show_confidence, show_ids, figsize)
#      34     img = image
#      36 fig, ax = plt.subplots(figsize=figsize)
# ---> 38 ax.imshow(img)
#      39 ax.axis("off")
#      41 for region in regions:
#
#     [... skipping hidden 1 frame]
#
# File ~/Downloads/madar_ai_test/.venv/lib/python3.14/site-packages/matplotlib/axes/_axes.py:6377, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    6374 if aspect is not None:
#    6375     self.set_aspect(aspect)
# -> 6377 im.set_data(X)
#    6378 im.set_alpha(alpha)
#    6379 if im.get_clip_path() is None:
#    6380     # image does not already have clipping set, clip to Axes patch
#
# File ~/Downloads/madar_ai_test/.venv/lib/python3.14/site-packages/matplotlib/image.py:716, in _ImageBase.set_data(self, A)
#     714 if isinstance(A, PIL.Image.Image):
#     715     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 716 self._A = self._normalize_image_array(A)
#     717 self._imcache = None
#     718 self.stale = True
#
# File ~/Downloads/madar_ai_test/.venv/lib/python3.14/site-packages/matplotlib/image.py:679, in _ImageBase._normalize_image_array(A)
#     677 A = cbook.safe_masked_invalid(A, copy=True)
#     678 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 679     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     680                     f"converted to float")
#     681 if A.ndim == 3 and A.shape[-1] == 1:
#     682     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype object cannot be converted to float

# %% [markdown]
# ### Against eScriptorium

# %%
compare_regions(
    source,
    [
        ("eScriptorium", escriptorium_regions),
        ("Qwen 8B", qwen_8b_regions),
    ],
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 compare_regions(
#       2     source,
#       3     [
#       4         ("eScriptorium", escriptorium_regions),
#
# File ~/Downloads/madar_ai_test/src/visualization.py:127, in compare_regions(image, region_sets, coordinate_max, figsize)
#     123     img = image
#     125 fig, ax = plt.subplots(figsize=figsize)
# --> 127 ax.imshow(img)
#     128 ax.axis("off")
#     130 for source_name, regions in region_sets:
#
#     [... skipping hidden 1 frame]
#
# File ~/Downloads/madar_ai_test/.venv/lib/python3.14/site-packages/matplotlib/axes/_axes.py:6377, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    6374 if aspect is not None:
#    6375     self.set_aspect(aspect)
# -> 6377 im.set_data(X)
#    6378 im.set_alpha(alpha)
#    6379 if im.get_clip_path() is None:
#    6380     # image does not already have clipping set, clip to Axes patch
#
# File ~/Downloads/madar_ai_test/.venv/lib/python3.14/site-packages/matplotlib/image.py:716, in _ImageBase.set_data(self, A)
#     714 if isinstance(A, PIL.Image.Image):
#     715     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 716 self._A = self._normalize_image_array(A)
#     717 self._imcache = None
#     718 self.stale = True
#
# File ~/Downloads/madar_ai_test/.venv/lib/python3.14/site-packages/matplotlib/image.py:679, in _ImageBase._normalize_image_array(A)
#     677 A = cbook.safe_masked_invalid(A, copy=True)
#     678 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 679     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     680                     f"converted to float")
#     681 if A.ndim == 3 and A.shape[-1] == 1:
#     682     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype object cannot be converted to float
